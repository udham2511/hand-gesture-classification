# %% [markdown]
# # **1. Importing Modules**

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dropout, Dense
from tensorflow import lite

from sklearn.metrics import confusion_matrix, classification_report
import seaborn
from matplotlib import pyplot
from sklearn.model_selection import train_test_split

import numpy
import os
import pandas

# %% [markdown]
# # **2. Loading Dataset**

# %%
labels = ["thumbsup", "thumbsdown", "pointing", "victory", "fist", "palm", "ILoveU", "ok"]

# %%
X = []
Y = []

for num, label in enumerate(labels):
    labeldata = numpy.load(os.path.join("../data", "gesture", label + ".npy"))

    X.extend(labeldata)
    Y.extend([num] * len(labeldata))

X = numpy.array(X)
Y = numpy.array(Y)

# %%
print("Total Samples:", len(X))
# Out:
# Total Samples: 40000

# %%
x_train, x_test, y_train, y_test = train_test_split(
    X, Y, train_size=0.95, random_state=42
)

# %% [markdown]
# # **3. Building Model**

# %%
model = Sequential(
    [
        Input(x_train[0].shape),
        Dropout(0.2),
        Dense(20, activation="relu"),
        Dropout(0.4),
        Dense(10, activation="relu"),
        Dense(len(labels), activation="softmax"),
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dropout_6 (Dropout)             │ (None, 42)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 20)             │           860 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 8)              │            88 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,158 (4.52 KB)
#  Trainable params: 1,158 (4.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # **4. Creating Callbacks**

# %%
dirpath = f"../models/{'-'.join(labels)}"

# %%
CPCallback = ModelCheckpoint(
    os.path.join(dirpath, "model.keras"), verbose=1, save_weights_only=False
)
ESCallback = EarlyStopping(patience=56, verbose=1)

# %% [markdown]
# # **5. Compiling Model**

# %%
model.compile(
    optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)

# %% [markdown]
# # **6. Training Model**

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(x_test, y_test),
    callbacks=[CPCallback, ESCallback],
)
# Out:
# Epoch 1/1000
# 275/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2057 - loss: 1.9461
# Epoch 1: saving model to ./models/thumbsup-thumbsdown-pointing-victory-fist-palm-ILoveU-ok\model.keras
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2117 - loss: 1.9330 - val_accuracy: 0.6155 - val_loss: 1.3830
# Epoch 2/1000
# 289/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4600 - loss: 1.3666
# Epoch 2: saving model to ./models/thumbsup-thumbsdown-pointing-victory-fist-palm-ILoveU-ok\model.keras
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4611 - loss: 1.3638 - val_accuracy: 0.8465 - val_loss: 0.8422
# Epoch 3/1000
# 278/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5667 - loss: 1.1001
# Epoch 3: saving model to ./models/thumbsup-thumbsdown-pointing-victory-fist-palm-ILoveU-ok\model.keras
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5681 - loss: 1.0973 - val_accuracy: 0.9080 - val_loss: 0.6305
# Epoch 4/1000
# 275/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6271 - loss: 0.9743
# Epoch 4: saving model to ./models/thumbsup-thumbsdown-pointing-victory-fist-palm-ILoveU-ok\model.keras
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6278 - loss: 0.9725 - val_accuracy: 0.9245 - val_loss: 0.5073
# Epoch 5/1000
# 250/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6570 - loss: 0.9077
# Epoch 5: saving model to ./models/thumbsup-thumbsdown-pointing-victory-fist-palm-ILoveU-ok\model.keras
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6586 - loss: 0.9040 - val_accuracy: 0.9335 - val_loss: 0.4547
# Epoch 6/1000
# 288/297 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.6780 - loss: 0.8518
# Epoch 6: saving model to ./models/thumbsup-thumbsdown-pointing-victory-fist-palm-ILoveU-ok\model.keras
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6781 - loss: 0.8514 - val_accuracy: 0.9465 - val_loss: 0.4039
# Epoch 7/1000
# 260/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6911 - loss: 0.8202
# Epoch 7: saving model to ./models/thumbsup-thumbsdown-pointing-victory-fist-palm-ILoveU-ok\model.keras
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6916 - loss: 0.8190 - val_accuracy: 0.9570 - val_loss: 0.3724
# Epoch 8/1000
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7006 - loss: 0.7880
# Epoch 8: saving model to ./models/thumbsup-thumbsdown-pointing-victory-fist-palm-ILoveU-ok\model.keras
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7007 - loss: 0.7880 - val_accuracy: 0.9685 - val_loss: 0.3414
# Epoch 9/1000
# 263/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7139 - loss: 0.7558
# Epoch 9: saving model to ./models/thumbsup-thumbsdown-pointing-victory-fist-palm-ILoveU-ok\model.keras
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7145 - loss: 0.7545 - val_accuracy: 0.9705 - val_loss: 0.3259
# Epoch 10/1000
# 292/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7289 - loss: 0.7277
# Epoch 10: saving model to ./models/thumbsup-thumbsdown-pointing-victory-fist-palm-ILoveU-ok\model.keras
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7290 - loss: 0.7275 - val_accuracy: 0.9725 - val_loss: 0.3023
# Epoch 11/1000
# 262/297 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.7423 - loss: 0.7014
# Epoch 11: saving model to ./models/thumbsup-thumbsdown-pointing-victory-fist-palm-ILoveU-ok\model.keras
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7425 - loss: 0.7004 - val_accuracy: 0.9885 - val_loss: 0.2786
# Epoch 12/1000
# 252/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7468 - loss: 0.6825
# Epoch 12: saving model to ./models/thumbsup-thumbsdown-pointing-victory-fist-palm-ILoveU-ok\model.keras
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.
297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8461 - loss: 0.4259
# Epoch 76: saving model to ./models/thumbsup-thumbsdown-pointing-victory-fist-palm-ILoveU-ok\model.keras
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8461 - loss: 0.4262 - val_accuracy: 0.8140 - val_loss: 0.4870
# Epoch 76: early stopping

# %%
with open(os.path.join(dirpath, "labels.txt"), "w") as file:
    file.write("\n".join(labels))

# %% [markdown]
# # **7. Plotting Loss And Accuracy**

# %%
pyplot.title("Model Accuracy")

pyplot.plot(history.history["accuracy"])
pyplot.plot(history.history["val_accuracy"])

pyplot.legend(["accuracy", "validation"])

pyplot.xlabel("epochs")
pyplot.ylabel("accuracy")

pyplot.savefig(os.path.join(dirpath, "accuracy.png"), bbox_inches="tight")
pyplot.show()

# %%
pyplot.title("Model Loss")

pyplot.plot(history.history["loss"])
pyplot.plot(history.history["val_loss"])

pyplot.legend(["accuracy", "validation"])

pyplot.xlabel("epochs")
pyplot.ylabel("loss")

pyplot.savefig(os.path.join(dirpath, "loss.png"), bbox_inches="tight")
pyplot.show()

# %% [markdown]
# # **8. Evaluation**

# %%
loss, accuracy = model.evaluate(x_test, y_test, batch_size=128)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8144 - loss: 0.4860

# %%
y_pred = numpy.argmax(model.predict(x_test, verbose=0), axis=1)

matrix = pandas.DataFrame(
    confusion_matrix(y_test, y_pred), index=labels, columns=labels
)

seaborn.heatmap(matrix, annot=True, fmt="g", square=False)

pyplot.title("Confusion Matrix")
pyplot.ylabel("Predicted Values")
pyplot.xlabel("Actual Values")

pyplot.savefig(os.path.join(dirpath, "confusion matrix.png"), bbox_inches="tight")
pyplot.show()

# %%
print("Classification Report: \n")
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     thumbsup       0.55      0.30      0.39       247
#   thumbsdown       1.00      1.00      1.00       245
#     pointing       0.95      1.00      0.97       243
#      victory       1.00      0.88      0.93       265
#         fist       0.49      0.84      0.62       258
#         palm       0.75      0.75      0.75       247
#       ILoveU       1.00      1.00      1.00       252
#           ok       0.96      0.74      0.84       243
#
#     accuracy                           0.81      2000
#    macro avg       0.84      0.81      0.81      2000
# weighted avg       0.84      0.81      0.81      2000

# %% [markdown]
# # **9. Converting To TFLITE**

# %%
converter = lite.TFLiteConverter.from_keras_model(model)

converter.optimizations = [lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open(os.path.join(dirpath, "model.tflite"), "wb") as file:
    file.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\udham\AppData\Local\Temp\tmp6yw4pipk\assets
# INFO:tensorflow:Assets written to: C:\Users\udham\AppData\Local\Temp\tmp6yw4pipk\assets
# Saved artifact at 'C:\Users\udham\AppData\Local\Temp\tmp6yw4pipk'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 42), dtype=tf.float32, name='keras_tensor_18')
# Output Type:
#   TensorSpec(shape=(None, 8), dtype=tf.float32, name=None)
# Captures:
#   1993861420080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1993980036016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1993992183072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1993992186416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1993992183600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1993980306256: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# # **10. Inference**

# %%
interpreter = lite.Interpreter(model_path=os.path.join(dirpath, "model.tflite"))
interpreter.allocate_tensors()

# %%
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
num = numpy.random.randint(len(x_test))

# %%
interpreter.set_tensor(input_details[0]["index"], numpy.array([x_test[num]], "float32"))

# %%
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]["index"])

# %%
tflite_results = labels[numpy.argmax(tflite_results)]
reality = labels[y_test[num]]

print(f"Prediction: {tflite_results}\nReality: {reality}")
# Out:
# Prediction: palm
# Reality: palm
